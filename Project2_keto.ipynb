# %% [markdown]
# ## Welcome to Group Sylvia Lane's project on Keto Diets! ##

# %% [markdown]
# ### Function: Dietary Reference Intakes

# %%
# Install packages
# %pip install eep153_tools >/dev/null
# %pip install gspread_pandas >/dev/null
# %pip install python-gnupg
# %pip install cufflinks
# %pip install fooddatacentral
# Import libraries
import numpy as np
import pandas as pd
import fooddatacentral as fdc
from eep153_tools.sheets import read_sheets

#API key 
apikey= "dUdHdPrImMUmSaiONq6fBWVnnuJAwDaHZkQqfa2L"
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Collecting python-gnupg
#   Using cached python_gnupg-0.5.2-py2.py3-none-any.whl (20 kB)
# Installing collected packages: python-gnupg
# Successfully installed python-gnupg-0.5.2
# Note: you may need to restart the kernel to use updated packages.
# Collecting cufflinks
#   Using cached cufflinks-0.17.3-py3-none-any.whl
# Requirement already satisfied: plotly>=4.1.1 in /srv/conda/lib/python3.9/site-packages (from cufflinks) (5.19.0)
# Requirement already satisfied: pandas>=0.19.2 in /srv/conda/lib/python3.9/site-packages (from cufflinks) (2.2.1)
# Requirement already satisfied: six>=1.9.0 in /srv/conda/lib/python3.9/site-packages (from cufflinks) (1.16.0)
# Requirement already satisfied: ipython>=5.3.0 in /srv/conda/lib/python3.9/site-packages (from cufflinks) (8.18.1)
# Requirement already satisfied: numpy>=1.9.2 in /srv/conda/lib/python3.9/site-packages (from cufflinks) (1.22.4)
# Requirement already satisfied: setuptools>=34.4.1 in /srv/conda/lib/python3.9/site-packages (from cufflinks) (59.8.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in /srv/conda/lib/python3.9/site-packages (from cufflinks) (8.0.7)
# Collecting colorlover>=0.2.1
#   Using cached colorlover-0.3.0-py3-none-any.whl (8.9 kB)
# Requirement already satisfied: pygments>=2.4.0 in /srv/conda/lib/python3.9/site-packages (from ipython>=5.3.0->cufflinks) (2.17.2)
# Requirement already satisfied: matplotlib-inline in /srv/conda/lib/python3.9/site-packages (from ipython>=5.3.0->cufflinks) (0.1.6)
# Requirement already satisfied: traitlets>=5 in /srv/conda/lib/python3.9/site-packages (from ipython>=5.3.0->cufflinks) (5.9.0)
# Requirement already satisfied: jedi>=0.16 in /srv/conda/lib/python3.9/site-packages (from ipython>=5.3.0->cufflinks) (0.19.1)
# Requirement already satisfied: exceptiongroup in /srv/conda/lib/python3.9/site-packages (from ipython>=5.3.0->cufflinks) (1.2.0)
# Requirement already satisfied: pexpect>4.3 in /srv/conda/lib/python3.9/site-packages (from ipython>=5.3.0->cufflinks) (4.9.0)
# Requirement already satisfied: stack-data in /srv/conda/lib/python3.9/site-packages (from ipython>=5.3.0->cufflinks) (0.6.2)
# Requirement already satisfied: typing-extensions in /srv/conda/lib/python3.9/site-packages (from ipython>=5.3.0->cufflinks) (4.10.0)
# Requirement already satisfied: decorator in /srv/conda/lib/python3.9/site-packages (from ipython>=5.3.0->cufflinks) (5.0.9)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /srv/conda/lib/python3.9/site-packages (from ipython>=5.3.0->cufflinks) (3.0.42)
# Requirement already satisfied: ipykernel>=4.5.1 in /srv/conda/lib/python3.9/site-packages (from ipywidgets>=7.0.0->cufflinks) (6.19.4)
# Requirement already satisfied: widgetsnbextension~=4.0.7 in /srv/conda/lib/python3.9/site-packages (from ipywidgets>=7.0.0->cufflinks) (4.0.10)
# Requirement already satisfied: jupyterlab-widgets~=3.0.7 in /srv/conda/lib/python3.9/site-packages (from ipywidgets>=7.0.0->cufflinks) (3.0.10)
# Requirement already satisfied: python-dateutil>=2.8.2 in /srv/conda/lib/python3.9/site-packages (from pandas>=0.19.2->cufflinks) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /srv/conda/lib/python3.9/site-packages (from pandas>=0.19.2->cufflinks) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /srv/conda/lib/python3.9/site-packages (from pandas>=0.19.2->cufflinks) (2024.1)
# Requirement already satisfied: tenacity>=6.2.0 in /srv/conda/lib/python3.9/site-packages (from plotly>=4.1.1->cufflinks) (8.2.3)
# Requirement already satisfied: packaging in /srv/conda/lib/python3.9/site-packages (from plotly>=4.1.1->cufflinks) (23.2)
# Requirement already satisfied: nest-asyncio in /srv/conda/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (1.6.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /srv/conda/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (8.6.0)
# Requirement already satisfied: psutil in /srv/conda/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (5.9.8)
# Requirement already satisfied: tornado>=6.1 in /srv/conda/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (6.4)
# Requirement already satisfied: pyzmq>=17 in /srv/conda/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (25.1.2)
# Requirement already satisfied: comm>=0.1.1 in /srv/conda/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (0.2.1)
# Requirement already satisfied: debugpy>=1.0 in /srv/conda/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (1.8.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /srv/conda/lib/python3.9/site-packages (from jedi>=0.16->ipython>=5.3.0->cufflinks) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /srv/conda/lib/python3.9/site-packages (from pexpect>4.3->ipython>=5.3.0->cufflinks) (0.7.0)
# Requirement already satisfied: wcwidth in /srv/conda/lib/python3.9/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->cufflinks) (0.2.13)
# Requirement already satisfied: asttokens>=2.1.0 in /srv/conda/lib/python3.9/site-packages (from stack-data->ipython>=5.3.0->cufflinks) (2.4.1)
# Requirement already satisfied: executing>=1.2.0 in /srv/conda/lib/python3.9/site-packages (from stack-data->ipython>=5.3.0->cufflinks) (2.0.1)
# Requirement already satisfied: pure-eval in /srv/conda/lib/python3.9/site-packages (from stack-data->ipython>=5.3.0->cufflinks) (0.2.2)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /srv/conda/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (5.7.1)
# Requirement already satisfied: importlib-metadata>=4.8.3 in /srv/conda/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (7.0.1)
# Requirement already satisfied: zipp>=0.5 in /srv/conda/lib/python3.9/site-packages (from importlib-metadata>=4.8.3->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (3.17.0)
# Requirement already satisfied: platformdirs>=2.5 in /srv/conda/lib/python3.9/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (4.2.0)
# Installing collected packages: colorlover, cufflinks
# Successfully installed colorlover-0.3.0 cufflinks-0.17.3
# Note: you may need to restart the kernel to use updated packages.
# Collecting fooddatacentral
#   Using cached fooddatacentral-1.0.10-py3-none-any.whl (6.8 kB)
# Installing collected packages: fooddatacentral
# Successfully installed fooddatacentral-1.0.10
# Note: you may need to restart the kernel to use updated packages.

# %%
RDIs = read_sheets('https://docs.google.com/spreadsheets/d/1y95IsQ4HKspPW3HHDtH7QMtlDA66IUsCHJLutVL-MMc/')

bmin = RDIs['diet_minimums'].set_index('Nutrition')

# Drop string describing source
bmin = bmin.drop('Source',axis=1)

bmin
# Out:
# Key available for students@eep153.iam.gserviceaccount.com.
# /srv/conda/lib/python3.9/site-packages/eep153_tools/sheets.py:150: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   D[w.title]=df.apply(lambda x: pd.to_numeric(x,errors='ignore'))
#                                  C 1-3   F 4-8   M 4-8  F 9-13  M 9-13  \
# Nutrition
# Energy                          1000.0  1200.0  1400.0  1600.0  1800.0
# Protein                           13.0    19.0    19.0    34.0    34.0
# Fiber, total dietary              14.0    16.8    19.6    22.4    25.2
# Folate, DFE                      150.0   200.0   200.0   300.0   300.0
# Calcium, Ca                      700.0  1000.0  1000.0  1300.0  1300.0
# Carbohydrate, by difference      130.0   130.0   130.0   130.0   130.0
# Iron, Fe                           7.0    10.0    10.0     8.0     8.0
# Magnesium, Mg                     80.0   130.0   130.0   240.0   240.0
# Niacin                             6.0     8.0     8.0    12.0    12.0
# Phosphorus, P                    460.0   500.0   500.0  1250.0  1250.0
# Potassium, K                    3000.0  3800.0  3800.0  4500.0  4500.0
# Riboflavin                         0.5     0.6     0.6     0.9     0.9
# Thiamin                            0.5     0.6     0.6     0.9     0.9
# Vitamin A, RAE                   300.0   400.0   400.0   600.0   600.0
# Vitamin B-12                       0.9     1.2     1.2     1.8     1.8
# Vitamin B-6                        0.5     0.6     0.6     1.0     1.0
# Vitamin C, total ascorbic acid    15.0    25.0    25.0    45.0    45.0
# Vitamin E (alpha-tocopherol)       6.0     7.0     7.0    11.0    11.0
# Vitamin K (phylloquinone)         30.0    55.0    55.0    60.0    60.0
# Zinc, Zn                           3.0     5.0     5.0     8.0     8.0
#
#                                 F 14-18  M 14-18  F 19-30  M 19-30  F 31-50  \
# Nutrition
# Energy                           1800.0   2200.0   2000.0   2400.0   1800.0
# Protein                            46.0     52.0     46.0     56.0     46.0
# Fiber, total dietary               25.2     30.8     28.0     33.6     25.2
# Folate, DFE                       400.0    400.0    400.0    400.0    400.0
# Calcium, Ca                      1300.0   1300.0   1000.0   1000.0   1000.0
# Carbohydrate, by difference       130.0    130.0    130.0    130.0    130.0
# Iron, Fe                           15.0     11.0     18.0      8.0     18.0
# Magnesium, Mg                     360.0    410.0    310.0    400.0    320.0
# Niacin                             14.0     16.0     14.0     16.0     14.0
# Phosphorus, P                    1250.0   1250.0    700.0    700.0    700.0
# Potassium, K                     4700.0   4700.0   4700.0   4700.0   4700.0
# Riboflavin                          1.0      1.3      1.1      1.3      1.1
# Thiamin                             1.0      1.2      1.1      1.2      1.1
# Vitamin A, RAE                    700.0    900.0    700.0    900.0    700.0
# Vitamin B-12                        2.4      2.4      2.4      2.4      2.4
# Vitamin B-6                         1.2      1.3      1.3      1.3      1.3
# Vitamin C, total ascorbic acid     65.0     75.0     75.0     90.0     75.0
# Vitamin E (alpha-tocopherol)       15.0     15.0     15.0     15.0     15.0
# Vitamin K (phylloquinone)          75.0     75.0     90.0    120.0     90.0
# Zinc, Zn                            9.0     11.0      8.0     11.0      8.0
#
#                                 M 31-50   F 51+   M 51+
# Nutrition
# Energy                           2200.0  1600.0  2000.0
# Protein                            56.0    46.0    56.0
# Fiber, total dietary               30.8    22.4    28.0
# Folate, DFE                       400.0   400.0   400.0
# Calcium, Ca                      1000.0  1200.0  1000.0
# Carbohydrate, by difference       130.0   130.0   130.0
# Iron, Fe                            8.0     8.0     8.0
# Magnesium, Mg                     420.0   320.0   420.0
# Niacin                             16.0    14.0    16.0
# Phosphorus, P                     700.0   700.0   700.0
# Potassium, K                     4700.0  4700.0  4700.0
# Riboflavin                          1.3     1.1     1.3
# Thiamin                             1.2     1.1     1.2
# Vitamin A, RAE                    900.0   700.0   900.0
# Vitamin B-12                        2.4     2.4     2.4
# Vitamin B-6                         1.3     1.5     1.7
# Vitamin C, total ascorbic acid     90.0    75.0    90.0
# Vitamin E (alpha-tocopherol)       15.0    15.0    15.0
# Vitamin K (phylloquinone)         120.0    90.0   120.0
# Zinc, Zn                           11.0     8.0    11.0

# %%
def diet_ref_intake(age,sex,df):
    #function inputs characteristics of individual, output df.series of reccomended nutrients#
    #each specific column selected returns a Series#
    if age <= 3:
        col = 'C 1-3'
    age_range_list = [(4,8),(9,13),(14,18),(19,30),(31,50),(50,100)]
    for age_range in age_range_list:
        if age >= age_range[0] and age <= age_range[1]:
            col = sex + ' ' + str(age_range[0]) + '-' + str(age_range[1])
    return pd.Series(df[col])

# %%
#Example for Diet Reference Intake for Female aged 12 years old in bmin dataframe#
diet_ref_intake(age=12,sex='F',df=bmin)
# Out:
# Nutrition
# Energy                            1600.0
# Protein                             34.0
# Fiber, total dietary                22.4
# Folate, DFE                        300.0
# Calcium, Ca                       1300.0
# Carbohydrate, by difference        130.0
# Iron, Fe                             8.0
# Magnesium, Mg                      240.0
# Niacin                              12.0
# Phosphorus, P                     1250.0
# Potassium, K                      4500.0
# Riboflavin                           0.9
# Thiamin                              0.9
# Vitamin A, RAE                     600.0
# Vitamin B-12                         1.8
# Vitamin B-6                          1.0
# Vitamin C, total ascorbic acid      45.0
# Vitamin E (alpha-tocopherol)        11.0
# Vitamin K (phylloquinone)           60.0
# Zinc, Zn                             8.0
# Name: F 9-13, dtype: float64

# %% [markdown]
# ## Next, Nutrients: #

# %%
apikey = "ngZTL3EoRoYFex00m5L4bdOdbtctFiuu7MT4cTeM"
#Installations
# %pip install -r requirements.txt
# %pip install python-gnupg
import fooddatacentral as fdc
import pandas as pd
from eep153_tools.sheets import read_sheets
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: python-gnupg in /srv/conda/lib/python3.9/site-packages (0.5.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
df = read_sheets('https://docs.google.com/spreadsheets/d/1CBbHwj62DyYoIubexC1uNchOYTM_qtdTCIVG-jco72s/',sheet="Keto Food Prices")

df = df.set_index('Food')
df = df.dropna(how='any') # Drop food with any missing data
df['FDC'] = df['FDC'].astype(int)
df['FDC'] = df['FDC'].astype(str)

df
# Out:
# Key available for students@eep153.iam.gserviceaccount.com.
# /srv/conda/lib/python3.9/site-packages/eep153_tools/sheets.py:165: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   return df.apply(lambda x: pd.to_numeric(x,errors='ignore'))
#                                        Quantity  Units  Price     Date  \
# Food
# salmon                                     7.00     oz   8.99  2/20/24
# tuna                                       5.00     oz   1.29  2/20/24
# chicken                                    1.25  pound   4.99  2/20/24
# cottage cheese                            16.00     oz   2.99  2/20/24
# greek yogurt                              32.00     oz   6.99  2/20/24
# spinach                                    8.00     oz   2.49  2/20/24
# carrots                                    1.00  pound   1.49  2/20/24
# kale                                      10.00     oz   3.99  2/20/24
# collard greens                             1.00  pound   3.49  2/20/24
# coconut milk                              13.50   floz   2.29  2/20/24
# squash                                     2.00  pound   1.20  2/23/24
# cauliflower                                1.00  pound   3.99  2/20/24
# broccoli                                   1.00  pound   3.49  2/20/24
# asparagus                                  1.00  pound   4.99  2/20/24
# green beans                               24.00     oz   1.99  2/20/24
# almonds                                   16.00     oz  10.99  2/20/24
# chia seeds                                16.00     oz   7.99  2/20/24
# olive oil                                 17.00   floz   7.99  2/20/24
# almond milk                               64.00   floz   3.49  2/20/24
# cod fillets                                1.00  pound  10.99  2/20/24
# pork loin                                  1.50  pound   8.99  2/20/24
# ground beef 80% lean 20% fat               1.00  pound   4.99  2/20/24
# avocado                                    5.40     oz   1.00  2/20/24
# egg                                       12.00    egg   5.49  2/20/24
# coconut oil                               14.00   floz   6.99  2/20/24
# almond flour                              16.00     oz   9.49  2/20/24
# mayonnaise                                15.00   floz   3.49  2/20/24
# cabbage                                    2.00  pound   2.98  2/20/24
# green bell pepper                          0.33  pound   1.00  2/20/24
# bacon                                      8.00     oz   4.99  2/20/24
# ground turkey                              1.00  pound   4.49  2/20/24
# tofu                                      14.00     oz   3.49  2/20/24
# kefir                                     32.00     oz   5.99  2/20/24
# hemp seeds                                 8.00     oz  12.79  2/20/24
# frozen berries                            12.00     oz   4.50  2/20/24
# zuchini noodles                           12.00     oz   4.99  2/20/24
# peanuts                                   16.00     oz   2.99  2/20/24
# walnuts                                   16.00     oz   5.00  2/20/24
# manzanilla olives                         14.50     oz   2.99  2/20/24
# apple                                      0.33  pound   0.49  2/20/24
# apple                                      5.00  pound   3.99  2/20/24
# tomato                                     0.33  pound   0.87  2/20/24
# spam                                       1.00     oz   3.99  2/20/24
# black beans                               15.50     oz   1.09  2/20/24
# cauliflower rice                          12.00     oz   1.99  2/20/24
# creamy almond butter no salt              16.00     oz   5.99  2/20/24
# creamy salted peanut butter               16.00     oz   2.49  2/20/24
# wild arugula                               7.00     oz   2.29  2/20/24
# traditional whole milk ricotta cheese     16.00     oz   3.99  2/20/24
#
#                                           Location      FDC
# Food
# salmon                                     Safeway   175167
# tuna                                       Safeway   175156
# chicken                                    Safeway  2646171
# cottage cheese                             Safeway  2346384
# greek yogurt                               Safeway  2259794
# spinach                                    Safeway  1999632
# carrots                                    Safeway  2258586
# kale                                       Safeway   323505
# collard greens                         trader joes   170406
# coconut milk                               Safeway   170173
# squash                                     Safeway   169295
# cauliflower                                Safeway   169986
# broccoli                                   Safeway   170379
# asparagus                                  Safeway   168389
# green beans                            trader joes   169961
# almonds                                    Safeway  2346393
# chia seeds                                 Safeway   170554
# olive oil                                  Safeway   748608
# almond milk                                Safeway  2257045
# cod fillets                            trader joes   171955
# pork loin                                  Safeway  2646169
# ground beef 80% lean 20% fat           trader joes  2514744
# avocado                                    Safeway   171706
# egg                                        Safeway   748967
# coconut oil                                Safeway   330458
# almond flour                               Safeway  2261420
# mayonnaise                                 Safeway   167736
# cabbage                                    Safeway   169975
# green bell pepper                           Safway  2258588
# bacon                                  trader joes   749420
# ground turkey                          trader joes  2514747
# tofu                                       Safeway   174292
# kefir                                     Safeway    170904
# hemp seeds                                Safeway    170148
# frozen berries                             Safeway  2344766
# zuchini noodles                           Safeway   2435691
# peanuts                                   Safeway   2515376
# walnuts                                   Safeway   2346394
# manzanilla olives                      trader joes   332791
# apple                                     Safeway   1750339
# apple                                      Safeway  2512381
# tomato                                     Safeway  1999634
# spam                                       Safeway   174594
# black beans                            trader joes   747444
# cauliflower rice                       trader joes  2377843
# creamy almond butter no salt            trade joes  1990977
# creamy salted peanut butter            trader joes  2465753
# wild arugula                           trader joes  2510503
# traditional whole milk ricotta cheese  trader joes  2055810

# %%
import fooddatacentral as fdc

# Convert food quantities to FDC units
df['FDC Quantity'] = df[['Quantity','Units']].T.apply(lambda x : fdc.units(x['Quantity'],x['Units']))

# Now divide price by the FDC Quantity to get, e.g., price per hectoliter
df['FDC Price'] = df['Price']/df['FDC Quantity']

df.dropna(how='any') # Drop food with any missing data

# To use minimum price observed
Prices = df.groupby('Food')['FDC Price'].min()

Prices
# Out:
# /srv/conda/lib/python3.9/site-packages/pandas/core/dtypes/cast.py:1598: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   result[:] = values
# Food
# almond flour                               2.092186868134488 / hectogram
# almond milk                              0.18439209254598768 / deciliter
# almonds                                   2.4228802614118043 / hectogram
# apple                                    0.17592888522353228 / hectogram
# asparagus                                  1.100106688302539 / hectogram
# avocado                                   0.6532215175848224 / hectogram
# bacon                                      2.200213376605078 / hectogram
# black beans                              0.24805560338737195 / hectogram
# broccoli                                  0.7694132950252227 / hectogram
# cabbage                                  0.32848877065546755 / hectogram
# carrots                                  0.32848877065546755 / hectogram
# cauliflower                               0.8796444261176615 / hectogram
# cauliflower rice                          0.5849598689972085 / hectogram
# chia seeds                                1.7614934748571718 / hectogram
# chicken                                   0.8800853506420312 / hectogram
# coconut milk                              0.5735860147201518 / deciliter
# coconut oil                               1.6882858477563043 / deciliter
# cod fillets                               2.4228802614118043 / hectogram
# collard greens                            0.7694132950252227 / hectogram
# cottage cheese                             0.659182163932784 / hectogram
# creamy almond butter no salt              1.3205689504874165 / hectogram
# creamy salted peanut butter               0.5489510328403452 / hectogram
# egg                                                     nan / milliliter
# frozen berries                            1.3227735731092654 / hectogram
# greek yogurt                               0.770515606336147 / hectogram
# green beans                              0.29247993449860427 / hectogram
# green bell pepper                         0.6680674611662956 / hectogram
# ground beef 80% lean 20% fat               1.100106688302539 / hectogram
# ground turkey                             0.9898755572101002 / hectogram
# hemp seeds                                 5.639424666689168 / hectogram
# kale                                      1.4074310817882583 / hectogram
# kefir                                     0.6602844752437083 / hectogram
# manzanilla olives                         0.7273734222706582 / hectogram
# mayonnaise                                0.7867395948628807 / deciliter
# olive oil                                 1.5892590669866216 / deciliter
# peanuts                                    0.659182163932784 / hectogram
# pork loin                                 1.3213038246946995 / hectogram
# salmon                                    4.5301845418103985 / hectogram
# spam                                      14.074310817882584 / hectogram
# spinach                                   1.0979020656806904 / hectogram
# squash                                   0.13227735731092652 / hectogram
# tofu                                      0.8793294800288259 / hectogram
# tomato                                    0.5812186912146772 / hectogram
# traditional whole milk ricotta cheese     0.8796444261176615 / hectogram
# tuna                                      0.9100682182991745 / hectogram
# walnuts                                   1.1023113109243878 / hectogram
# wild arugula                              1.1539624694934163 / hectogram
# zuchini noodles                           1.4668089177367187 / hectogram
# Name: FDC Price, dtype: object

# %%
import warnings

D = {}
count = 0
for food in  df.index:
    try:
        FDC = df.loc[df.index==food,:].FDC.values[0]
        count+=1
        D[food] = fdc.nutrients(apikey,FDC).Quantity
        print(food)
    except AttributeError:
        warnings.warn(f"Couldn't find FDC Code {FDC} for food {food}.")

D = pd.DataFrame(D,dtype=float)

D
# Out:
# salmon
# tuna
# chicken
# cottage cheese
# greek yogurt
# spinach
# carrots
# kale
# collard greens
# coconut milk
# squash
# cauliflower
# broccoli
# asparagus
# green beans
# almonds
# chia seeds
# olive oil
# almond milk
# cod fillets
# pork loin
# ground beef 80% lean 20% fat
# avocado
# egg
# coconut oil
# almond flour
# mayonnaise
# cabbage
# green bell pepper
# bacon
# ground turkey
# tofu
# kefir
# hemp seeds
# frozen berries
# zuchini noodles
# peanuts
# walnuts
# manzanilla olives
# apple
# apple
# tomato
# spam
# black beans
# cauliflower rice
# creamy almond butter no salt
# creamy salted peanut butter
# wild arugula
# traditional whole milk ricotta cheese
#                            salmon   tuna  chicken  cottage cheese  \
# 25-hydroxycholecalciferol     NaN    NaN      NaN             NaN
# Alanine                     1.271  1.331      NaN             NaN
# Alcohol, ethyl              0.000    NaN      NaN             NaN
# Amino acids                 0.000  0.000      NaN             NaN
# Arginine                    1.221  1.316      NaN             NaN
# ...                           ...    ...      ...             ...
# cis-Lutein/Zeaxanthin         NaN    NaN      NaN             NaN
# cis-Lycopene                  NaN    NaN      NaN             NaN
# cis-beta-Carotene             NaN    NaN      NaN             NaN
# trans-Lycopene                NaN    NaN      NaN             NaN
# trans-beta-Carotene           NaN    NaN      NaN             NaN
#
#                            greek yogurt  spinach  carrots  kale  \
# 25-hydroxycholecalciferol           NaN      NaN      NaN   NaN
# Alanine                             NaN      NaN      NaN   NaN
# Alcohol, ethyl                      NaN      NaN      NaN   NaN
# Amino acids                         NaN      NaN      NaN   NaN
# Arginine                            NaN      NaN      NaN   NaN
# ...                                 ...      ...      ...   ...
# cis-Lutein/Zeaxanthin               NaN      0.0      NaN   NaN
# cis-Lycopene                        NaN      NaN      NaN   NaN
# cis-beta-Carotene                   NaN      NaN      NaN   NaN
# trans-Lycopene                      NaN      NaN      NaN   NaN
# trans-beta-Carotene                 NaN      NaN      NaN   NaN
#
#                            collard greens  coconut milk  ...  \
# 25-hydroxycholecalciferol             NaN           NaN  ...
# Alanine                             0.105         0.103  ...
# Alcohol, ethyl                      0.000           NaN  ...
# Amino acids                         0.000         0.000  ...
# Arginine                            0.125         0.331  ...
# ...                                   ...           ...  ...
# cis-Lutein/Zeaxanthin                 NaN           NaN  ...
# cis-Lycopene                          NaN           NaN  ...
# cis-beta-Carotene                     NaN           NaN  ...
# trans-Lycopene                        NaN           NaN  ...
# trans-beta-Carotene                   NaN           NaN  ...
#
#                            manzanilla olives  apple  tomato  spam  \
# 25-hydroxycholecalciferol                NaN    NaN     NaN   NaN
# Alanine                                  NaN    NaN     NaN   NaN
# Alcohol, ethyl                           NaN    NaN     NaN   0.0
# Amino acids                              NaN    NaN     NaN   0.0
# Arginine                                 NaN    NaN     NaN   NaN
# ...                                      ...    ...     ...   ...
# cis-Lutein/Zeaxanthin                    NaN    NaN     0.0   NaN
# cis-Lycopene                             NaN    NaN     NaN   NaN
# cis-beta-Carotene                        NaN    NaN     NaN   NaN
# trans-Lycopene                           NaN    NaN     NaN   NaN
# trans-beta-Carotene                      NaN    NaN     NaN   NaN
#
#                            black beans  cauliflower rice  \
# 25-hydroxycholecalciferol          NaN               NaN
# Alanine                            NaN               NaN
# Alcohol, ethyl                     NaN               NaN
# Amino acids                        NaN               NaN
# Arginine                           NaN               NaN
# ...                                ...               ...
# cis-Lutein/Zeaxanthin              NaN               NaN
# cis-Lycopene                       NaN               NaN
# cis-beta-Carotene                  NaN               NaN
# trans-Lycopene                     NaN               NaN
# trans-beta-Carotene                NaN               NaN
#
#                            creamy almond butter no salt  \
# 25-hydroxycholecalciferol                           NaN
# Alanine                                             NaN
# Alcohol, ethyl                                      NaN
# Amino acids                                         NaN
# Arginine                                            NaN
# ...                                                 ...
# cis-Lutein/Zeaxanthin                               NaN
# cis-Lycopene                                        NaN
# cis-beta-Carotene                                   NaN
# trans-Lycopene                                      NaN
# trans-beta-Carotene                                 NaN
#
#                            creamy salted peanut butter  wild arugula  \
# 25-hydroxycholecalciferol                          NaN           NaN
# Alanine                                            NaN           NaN
# Alcohol, ethyl                                     NaN           NaN
# Amino acids                                        NaN           NaN
# Arginine                                           NaN           NaN
# ...                                                ...           ...
# cis-Lutein/Zeaxanthin                              NaN           NaN
# cis-Lycopene                                       NaN           NaN
# cis-beta-Carotene                                  NaN           NaN
# trans-Lycopene                                     NaN           NaN
# trans-beta-Carotene                                NaN           NaN
#
#                            traditional whole milk ricotta cheese
# 25-hydroxycholecalciferol                                    NaN
# Alanine                                                      NaN
# Alcohol, ethyl                                               NaN
# Amino acids                                                  NaN
# Arginine                                                     NaN
# ...                                                          ...
# cis-Lutein/Zeaxanthin                                        NaN
# cis-Lycopene                                                 NaN
# cis-beta-Carotene                                            NaN
# trans-Lycopene                                               NaN
# trans-beta-Carotene                                          NaN
#
# [213 rows x 48 columns]

# %%
RDIs = read_sheets('https://docs.google.com/spreadsheets/d/1y95IsQ4HKspPW3HHDtH7QMtlDA66IUsCHJLutVL-MMc/')

bmin = RDIs['diet_minimums'].set_index('Nutrition')

# Drop string describing source
bmin = bmin.drop('Source',axis=1)

bmin
# Out:
# Key available for students@eep153.iam.gserviceaccount.com.
# /srv/conda/lib/python3.9/site-packages/eep153_tools/sheets.py:150: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   D[w.title]=df.apply(lambda x: pd.to_numeric(x,errors='ignore'))
#                                  C 1-3   F 4-8   M 4-8  F 9-13  M 9-13  \
# Nutrition
# Energy                          1000.0  1200.0  1400.0  1600.0  1800.0
# Protein                           13.0    19.0    19.0    34.0    34.0
# Fiber, total dietary              14.0    16.8    19.6    22.4    25.2
# Folate, DFE                      150.0   200.0   200.0   300.0   300.0
# Calcium, Ca                      700.0  1000.0  1000.0  1300.0  1300.0
# Carbohydrate, by difference      130.0   130.0   130.0   130.0   130.0
# Iron, Fe                           7.0    10.0    10.0     8.0     8.0
# Magnesium, Mg                     80.0   130.0   130.0   240.0   240.0
# Niacin                             6.0     8.0     8.0    12.0    12.0
# Phosphorus, P                    460.0   500.0   500.0  1250.0  1250.0
# Potassium, K                    3000.0  3800.0  3800.0  4500.0  4500.0
# Riboflavin                         0.5     0.6     0.6     0.9     0.9
# Thiamin                            0.5     0.6     0.6     0.9     0.9
# Vitamin A, RAE                   300.0   400.0   400.0   600.0   600.0
# Vitamin B-12                       0.9     1.2     1.2     1.8     1.8
# Vitamin B-6                        0.5     0.6     0.6     1.0     1.0
# Vitamin C, total ascorbic acid    15.0    25.0    25.0    45.0    45.0
# Vitamin E (alpha-tocopherol)       6.0     7.0     7.0    11.0    11.0
# Vitamin K (phylloquinone)         30.0    55.0    55.0    60.0    60.0
# Zinc, Zn                           3.0     5.0     5.0     8.0     8.0
#
#                                 F 14-18  M 14-18  F 19-30  M 19-30  F 31-50  \
# Nutrition
# Energy                           1800.0   2200.0   2000.0   2400.0   1800.0
# Protein                            46.0     52.0     46.0     56.0     46.0
# Fiber, total dietary               25.2     30.8     28.0     33.6     25.2
# Folate, DFE                       400.0    400.0    400.0    400.0    400.0
# Calcium, Ca                      1300.0   1300.0   1000.0   1000.0   1000.0
# Carbohydrate, by difference       130.0    130.0    130.0    130.0    130.0
# Iron, Fe                           15.0     11.0     18.0      8.0     18.0
# Magnesium, Mg                     360.0    410.0    310.0    400.0    320.0
# Niacin                             14.0     16.0     14.0     16.0     14.0
# Phosphorus, P                    1250.0   1250.0    700.0    700.0    700.0
# Potassium, K                     4700.0   4700.0   4700.0   4700.0   4700.0
# Riboflavin                          1.0      1.3      1.1      1.3      1.1
# Thiamin                             1.0      1.2      1.1      1.2      1.1
# Vitamin A, RAE                    700.0    900.0    700.0    900.0    700.0
# Vitamin B-12                        2.4      2.4      2.4      2.4      2.4
# Vitamin B-6                         1.2      1.3      1.3      1.3      1.3
# Vitamin C, total ascorbic acid     65.0     75.0     75.0     90.0     75.0
# Vitamin E (alpha-tocopherol)       15.0     15.0     15.0     15.0     15.0
# Vitamin K (phylloquinone)          75.0     75.0     90.0    120.0     90.0
# Zinc, Zn                            9.0     11.0      8.0     11.0      8.0
#
#                                 M 31-50   F 51+   M 51+
# Nutrition
# Energy                           2200.0  1600.0  2000.0
# Protein                            56.0    46.0    56.0
# Fiber, total dietary               30.8    22.4    28.0
# Folate, DFE                       400.0   400.0   400.0
# Calcium, Ca                      1000.0  1200.0  1000.0
# Carbohydrate, by difference       130.0   130.0   130.0
# Iron, Fe                            8.0     8.0     8.0
# Magnesium, Mg                     420.0   320.0   420.0
# Niacin                             16.0    14.0    16.0
# Phosphorus, P                     700.0   700.0   700.0
# Potassium, K                     4700.0  4700.0  4700.0
# Riboflavin                          1.3     1.1     1.3
# Thiamin                             1.2     1.1     1.2
# Vitamin A, RAE                    900.0   700.0   900.0
# Vitamin B-12                        2.4     2.4     2.4
# Vitamin B-6                         1.3     1.5     1.7
# Vitamin C, total ascorbic acid     90.0    75.0    90.0
# Vitamin E (alpha-tocopherol)       15.0    15.0    15.0
# Vitamin K (phylloquinone)         120.0    90.0   120.0
# Zinc, Zn                           11.0     8.0    11.0

# %% [markdown]
# # Maxmum Quantities Required  #

# %%
# Maximum Quantities Required
bmax = RDIs['diet_maximums'].set_index('Nutrition')

# Drop string describing source
bmax = bmax.drop('Source',axis=1)

bmax
# Out:
#             C 1-3  F 4-8  M 4-8  F 9-13  M 9-13  F 14-18  M 14-18  F 19-30  \
# Nutrition
# Sodium, Na   1500   1900   1900    2200    2200     2300     2300     2300
# Energy       2500   2500   2500    2800    3000     3100     3100     3100
#
#             M 19-30  F 31-50  M 31-50  F 51+  M 51+
# Nutrition
# Sodium, Na     2300     2300     2300   2300   2300
# Energy         3100     3100     3100   3100   3100

# %%
p = Prices.apply(lambda x:x.magnitude).dropna()

# Compile list that we have both prices and nutritional info for; drop if either missing
use = p.index.intersection(D.columns)
p = p[use]

p
# Out:
# almond flour                              2.092187
# almond milk                               0.184392
# almonds                                   2.422880
# apple                                     0.175929
# asparagus                                 1.100107
# avocado                                   0.653222
# bacon                                     2.200213
# black beans                               0.248056
# broccoli                                  0.769413
# cabbage                                   0.328489
# carrots                                   0.328489
# cauliflower                               0.879644
# cauliflower rice                          0.584960
# chia seeds                                1.761493
# chicken                                   0.880085
# coconut milk                              0.573586
# coconut oil                               1.688286
# cod fillets                               2.422880
# collard greens                            0.769413
# cottage cheese                            0.659182
# creamy almond butter no salt              1.320569
# creamy salted peanut butter               0.548951
# frozen berries                            1.322774
# greek yogurt                              0.770516
# green beans                               0.292480
# green bell pepper                         0.668067
# ground beef 80% lean 20% fat              1.100107
# ground turkey                             0.989876
# hemp seeds                                5.639425
# kale                                      1.407431
# kefir                                     0.660284
# manzanilla olives                         0.727373
# mayonnaise                                0.786740
# olive oil                                 1.589259
# peanuts                                   0.659182
# pork loin                                 1.321304
# salmon                                    4.530185
# spam                                     14.074311
# spinach                                   1.097902
# squash                                    0.132277
# tofu                                      0.879329
# tomato                                    0.581219
# traditional whole milk ricotta cheese     0.879644
# tuna                                      0.910068
# walnuts                                   1.102311
# wild arugula                              1.153962
# zuchini noodles                           1.466809
# Name: FDC Price, dtype: float64

# %%
# Drop nutritional information for foods we don't know the price of,
# and replace missing nutrients with zeros.
Aall = D[p.index].fillna(0)

# Drop rows of A that we don't have constraints for.
Amin = Aall.loc[bmin.index]

Amax = Aall.loc[bmax.index]

# Maximum requirements involve multiplying constraint by -1 to make <=.
A = pd.concat([Amin,-Amax])

A
# Out:
#                                 almond flour  almond milk    almonds  \
# Nutrition
# Energy                               0.00000      0.00000    0.00000
# Protein                             26.24375      0.65625   21.45038
# Fiber, total dietary                 9.26600      0.00000   10.78000
# Folate, DFE                          0.00000      0.00000    0.00000
# Calcium, Ca                        232.30000    157.50000  253.60000
# Carbohydrate, by difference         16.24925      0.67075   20.03462
# Iron, Fe                             3.22500      0.12470    3.74100
# Magnesium, Mg                      251.10000      8.24900  257.60000
# Niacin                               3.99800      0.08875    3.77000
# Phosphorus, P                      512.10000     19.08000  502.90000
# Potassium, K                       666.80000     49.27000  732.80000
# Riboflavin                           0.74750      0.08333    0.00000
# Thiamin                              0.11250      0.00500    0.16050
# Vitamin A, RAE                       0.00000      0.00000    0.00000
# Vitamin B-12                         0.00000      0.44920    0.00000
# Vitamin B-6                          0.09988      0.00000    0.10080
# Vitamin C, total ascorbic acid       0.00000      0.00000    0.00000
# Vitamin E (alpha-tocopherol)         0.00000      0.00000    0.00000
# Vitamin K (phylloquinone)            0.00000      0.00000    0.00000
# Zinc, Zn                             2.79500      0.07661    2.86500
# Sodium, Na                          -0.89440    -59.22000   -0.00000
# Energy                              -0.00000     -0.00000   -0.00000
#
#                                    apple  asparagus  avocado    bacon  \
# Nutrition
# Energy                           0.00000     85.000  697.000  2090.00
# Protein                          0.18750      2.200    1.960    40.90
# Fiber, total dietary             2.04300      2.100    6.800     0.00
# Folate, DFE                      0.00000     52.000   89.000     0.00
# Calcium, Ca                      4.65600     24.000   13.000    13.00
# Carbohydrate, by difference     14.78170      3.880    8.640     2.10
# Iron, Fe                         0.00000      2.140    0.610     1.28
# Magnesium, Mg                    4.69500     14.000   29.000    36.50
# Niacin                           0.09000      0.978    1.912     0.00
# Phosphorus, P                    9.18300     52.000   54.000   415.00
# Potassium, K                    95.31000    202.000  507.000   557.00
# Riboflavin                       0.06625      0.141    0.143     0.00
# Thiamin                          0.00875      0.143    0.075     0.00
# Vitamin A, RAE                   0.00000     38.000    7.000     0.00
# Vitamin B-12                     0.00000      0.000    0.000     0.00
# Vitamin B-6                      0.02131      0.091    0.287     0.00
# Vitamin C, total ascorbic acid   0.00000      5.600    8.800     0.00
# Vitamin E (alpha-tocopherol)     0.00000      1.130    1.970     0.00
# Vitamin K (phylloquinone)        0.00000     41.600   21.000     0.00
# Zinc, Zn                         0.01964      0.540    0.680     3.56
# Sodium, Na                      -0.00000     -2.000   -8.000 -1830.00
# Energy                          -0.00000    -85.000 -697.000 -2090.00
#
#                                 black beans  broccoli  cabbage  ...      spam  \
# Nutrition                                                       ...
# Energy                                 0.00   141.000  103.000  ...   819.000
# Protein                               24.40     2.820    1.280  ...    15.230
# Fiber, total dietary                   4.20     2.600    2.500  ...     0.000
# Folate, DFE                            0.00    63.000   43.000  ...     4.000
# Calcium, Ca                          191.00    47.000   40.000  ...    39.000
# Carbohydrate, by difference            0.00     6.640    5.800  ...     1.350
# Iron, Fe                               5.34     0.730    0.470  ...     1.400
# Magnesium, Mg                        180.00    21.000   12.000  ...    18.000
# Niacin                                 0.00     0.639    0.234  ...     3.450
# Phosphorus, P                        522.00    66.000   26.000  ...   109.000
# Potassium, K                        1540.00   316.000  170.000  ...   461.000
# Riboflavin                             0.00     0.117    0.040  ...     0.210
# Thiamin                                0.00     0.071    0.061  ...     0.180
# Vitamin A, RAE                         0.00    31.000    5.000  ...     0.000
# Vitamin B-12                           0.00     0.000    0.000  ...     0.610
# Vitamin B-6                            0.00     0.175    0.124  ...     0.283
# Vitamin C, total ascorbic acid         0.00    89.200   36.600  ...    38.500
# Vitamin E (alpha-tocopherol)           0.00     0.780    0.150  ...     0.240
# Vitamin K (phylloquinone)              0.00   101.600   76.000  ...     0.000
# Zinc, Zn                               3.37     0.410    0.180  ...     2.200
# Sodium, Na                            -0.00   -33.000  -18.000  ... -1032.000
# Energy                                -0.00  -141.000 -103.000  ...  -819.000
#
#                                    spinach   squash     tofu      tomato  \
# Nutrition
# Energy                            0.000000  188.000  231.000    0.000000
# Protein                           2.851875    1.000    4.800    0.695625
# Fiber, total dietary              1.558000    2.000    0.100    0.970600
# Folate, DFE                       0.000000   27.000    0.000    0.000000
# Calcium, Ca                      68.350000   48.000   31.000    9.963000
# Carbohydrate, by difference       2.406325   11.690    2.900    3.837475
# Iron, Fe                          1.261000    0.700    0.820    0.103100
# Magnesium, Mg                    92.860000   34.000   29.000    8.089000
# Niacin                            0.550600    1.200    0.300    0.533100
# Phosphorus, P                    39.050000   33.000   62.000   19.090000
# Potassium, K                    581.800000  352.000  180.000  192.800000
# Riboflavin                        0.193500    0.020    0.040    0.000000
# Thiamin                           0.076880    0.100    0.100    0.055750
# Vitamin A, RAE                  283.000000  532.000    0.000   23.900000
# Vitamin B-12                      0.000000    0.000    0.000    0.000000
# Vitamin B-6                       0.194600    0.154    0.011    0.078940
# Vitamin C, total ascorbic acid   26.520000   21.000    0.000   17.750000
# Vitamin E (alpha-tocopherol)      0.000000    1.440    0.000    0.000000
# Vitamin K (phylloquinone)         0.000000    1.100    0.000    0.000000
# Zinc, Zn                          0.447100    0.150    0.520    0.082450
# Sodium, Na                     -111.400000   -4.000   -5.000   -0.000000
# Energy                           -0.000000 -188.000 -231.000   -0.000000
#
#                                 traditional whole milk ricotta cheese  \
# Nutrition
# Energy                                                         145.00
# Protein                                                         11.29
# Fiber, total dietary                                             0.00
# Folate, DFE                                                      0.00
# Calcium, Ca                                                    242.00
# Carbohydrate, by difference                                      4.84
# Iron, Fe                                                         0.58
# Magnesium, Mg                                                    0.00
# Niacin                                                           0.00
# Phosphorus, P                                                    0.00
# Potassium, K                                                     0.00
# Riboflavin                                                       0.00
# Thiamin                                                          0.00
# Vitamin A, RAE                                                   0.00
# Vitamin B-12                                                     0.00
# Vitamin B-6                                                      0.00
# Vitamin C, total ascorbic acid                                   0.00
# Vitamin E (alpha-tocopherol)                                     0.00
# Vitamin K (phylloquinone)                                        0.00
# Zinc, Zn                                                         0.00
# Sodium, Na                                                    -121.00
# Energy                                                        -145.00
#
#                                    tuna   walnuts  wild arugula  \
# Nutrition
# Energy                          431.000    0.0000         47.00
# Protein                          22.000   14.5644          3.53
# Fiber, total dietary              0.000    5.2100          2.40
# Folate, DFE                       9.000    0.0000          0.00
# Calcium, Ca                      29.000   88.2600        282.00
# Carbohydrate, by difference       0.000   10.9096          5.88
# Iron, Fe                          1.250    2.2350          1.69
# Magnesium, Mg                    34.000  142.4000          0.00
# Niacin                           15.400    1.2180          0.00
# Phosphorus, P                   222.000  365.1000          0.00
# Potassium, K                    407.000  423.5000          0.00
# Riboflavin                        0.100    0.0000          0.00
# Thiamin                           0.033    0.2300          0.00
# Vitamin A, RAE                   16.000    0.0000          0.00
# Vitamin B-12                      1.900    0.0000          0.00
# Vitamin B-6                       0.850    0.6603          0.00
# Vitamin C, total ascorbic acid    1.000    0.0000         21.20
# Vitamin E (alpha-tocopherol)      0.000    0.0000          0.00
# Vitamin K (phylloquinone)         0.000    1.7000          0.00
# Zinc, Zn                          0.820    2.7600          0.00
# Sodium, Na                      -37.000   -0.0000        -45.00
# Energy                         -431.000   -0.0000        -47.00
#
#                                 zuchini noodles
# Nutrition
# Energy                                    18.00
# Protein                                    1.18
# Fiber, total dietary                       1.20
# Folate, DFE                                0.00
# Calcium, Ca                               16.00
# Carbohydrate, by difference                3.53
# Iron, Fe                                   0.00
# Magnesium, Mg                              0.00
# Niacin                                     0.00
# Phosphorus, P                              0.00
# Potassium, K                             261.00
# Riboflavin                                 0.00
# Thiamin                                    0.00
# Vitamin A, RAE                             0.00
# Vitamin B-12                               0.00
# Vitamin B-6                                0.00
# Vitamin C, total ascorbic acid             0.00
# Vitamin E (alpha-tocopherol)               0.00
# Vitamin K (phylloquinone)                  0.00
# Zinc, Zn                                   0.00
# Sodium, Na                                -6.00
# Energy                                   -18.00
#
# [22 rows x 47 columns]

# %%
b = pd.concat([bmin,-bmax]) # Note sign change for max constraints

b
# Out:
#                                  C 1-3   F 4-8   M 4-8  F 9-13  M 9-13  \
# Nutrition
# Energy                          1000.0  1200.0  1400.0  1600.0  1800.0
# Protein                           13.0    19.0    19.0    34.0    34.0
# Fiber, total dietary              14.0    16.8    19.6    22.4    25.2
# Folate, DFE                      150.0   200.0   200.0   300.0   300.0
# Calcium, Ca                      700.0  1000.0  1000.0  1300.0  1300.0
# Carbohydrate, by difference      130.0   130.0   130.0   130.0   130.0
# Iron, Fe                           7.0    10.0    10.0     8.0     8.0
# Magnesium, Mg                     80.0   130.0   130.0   240.0   240.0
# Niacin                             6.0     8.0     8.0    12.0    12.0
# Phosphorus, P                    460.0   500.0   500.0  1250.0  1250.0
# Potassium, K                    3000.0  3800.0  3800.0  4500.0  4500.0
# Riboflavin                         0.5     0.6     0.6     0.9     0.9
# Thiamin                            0.5     0.6     0.6     0.9     0.9
# Vitamin A, RAE                   300.0   400.0   400.0   600.0   600.0
# Vitamin B-12                       0.9     1.2     1.2     1.8     1.8
# Vitamin B-6                        0.5     0.6     0.6     1.0     1.0
# Vitamin C, total ascorbic acid    15.0    25.0    25.0    45.0    45.0
# Vitamin E (alpha-tocopherol)       6.0     7.0     7.0    11.0    11.0
# Vitamin K (phylloquinone)         30.0    55.0    55.0    60.0    60.0
# Zinc, Zn                           3.0     5.0     5.0     8.0     8.0
# Sodium, Na                     -1500.0 -1900.0 -1900.0 -2200.0 -2200.0
# Energy                         -2500.0 -2500.0 -2500.0 -2800.0 -3000.0
#
#                                 F 14-18  M 14-18  F 19-30  M 19-30  F 31-50  \
# Nutrition
# Energy                           1800.0   2200.0   2000.0   2400.0   1800.0
# Protein                            46.0     52.0     46.0     56.0     46.0
# Fiber, total dietary               25.2     30.8     28.0     33.6     25.2
# Folate, DFE                       400.0    400.0    400.0    400.0    400.0
# Calcium, Ca                      1300.0   1300.0   1000.0   1000.0   1000.0
# Carbohydrate, by difference       130.0    130.0    130.0    130.0    130.0
# Iron, Fe                           15.0     11.0     18.0      8.0     18.0
# Magnesium, Mg                     360.0    410.0    310.0    400.0    320.0
# Niacin                             14.0     16.0     14.0     16.0     14.0
# Phosphorus, P                    1250.0   1250.0    700.0    700.0    700.0
# Potassium, K                     4700.0   4700.0   4700.0   4700.0   4700.0
# Riboflavin                          1.0      1.3      1.1      1.3      1.1
# Thiamin                             1.0      1.2      1.1      1.2      1.1
# Vitamin A, RAE                    700.0    900.0    700.0    900.0    700.0
# Vitamin B-12                        2.4      2.4      2.4      2.4      2.4
# Vitamin B-6                         1.2      1.3      1.3      1.3      1.3
# Vitamin C, total ascorbic acid     65.0     75.0     75.0     90.0     75.0
# Vitamin E (alpha-tocopherol)       15.0     15.0     15.0     15.0     15.0
# Vitamin K (phylloquinone)          75.0     75.0     90.0    120.0     90.0
# Zinc, Zn                            9.0     11.0      8.0     11.0      8.0
# Sodium, Na                      -2300.0  -2300.0  -2300.0  -2300.0  -2300.0
# Energy                          -3100.0  -3100.0  -3100.0  -3100.0  -3100.0
#
#                                 M 31-50   F 51+   M 51+
# Nutrition
# Energy                           2200.0  1600.0  2000.0
# Protein                            56.0    46.0    56.0
# Fiber, total dietary               30.8    22.4    28.0
# Folate, DFE                       400.0   400.0   400.0
# Calcium, Ca                      1000.0  1200.0  1000.0
# Carbohydrate, by difference       130.0   130.0   130.0
# Iron, Fe                            8.0     8.0     8.0
# Magnesium, Mg                     420.0   320.0   420.0
# Niacin                             16.0    14.0    16.0
# Phosphorus, P                     700.0   700.0   700.0
# Potassium, K                     4700.0  4700.0  4700.0
# Riboflavin                          1.3     1.1     1.3
# Thiamin                             1.2     1.1     1.2
# Vitamin A, RAE                    900.0   700.0   900.0
# Vitamin B-12                        2.4     2.4     2.4
# Vitamin B-6                         1.3     1.5     1.7
# Vitamin C, total ascorbic acid     90.0    75.0    90.0
# Vitamin E (alpha-tocopherol)       15.0    15.0    15.0
# Vitamin K (phylloquinone)         120.0    90.0   120.0
# Zinc, Zn                           11.0     8.0    11.0
# Sodium, Na                      -2300.0 -2300.0 -2300.0
# Energy                          -3100.0 -3100.0 -3100.0

# %%
from  scipy.optimize import linprog as lp
import numpy as np

tol = 1e-6 # Numbers in solution smaller than this (in absolute value) treated as zeros

## Choose sex/age group!
group = "F 19-30"

result = lp(p, -A, -b[group], method='highs')

result
# Out:
#         message: Optimization terminated successfully. (HiGHS Status 7: Optimal)
#         success: True
#          status: 0
#             fun: 3.9106343136306156
#               x: [ 0.000e+00  5.343e+00 ...  0.000e+00  0.000e+00]
#             nit: 12
#           lower:  residual: [ 0.000e+00  5.343e+00 ...  0.000e+00
#                               0.000e+00]
#                  marginals: [ 6.966e-01  0.000e+00 ...  1.154e+00
#                               1.467e+00]
#           upper:  residual: [       inf        inf ...        inf
#                                     inf]
#                  marginals: [ 0.000e+00  0.000e+00 ...  0.000e+00
#                               0.000e+00]
#           eqlin:  residual: []
#                  marginals: []
#         ineqlin:  residual: [ 3.401e+02  1.208e+01 ...  1.919e+03
#                               7.599e+02]
#                  marginals: [-0.000e+00 -0.000e+00 ... -0.000e+00
#                              -0.000e+00]
#  mip_node_count: 0
#  mip_dual_bound: 0.0
#         mip_gap: 0.0

# %%
print(f"Cost of diet for {group} is ${result.fun:.2f} per day.")
# Out:
# Cost of diet for F 19-30 is $3.91 per day.

# %%
diet = pd.Series(result.x,index=p.index)

print("\nYou'll be eating (in 100s of grams or milliliters):")
print(diet[diet >= tol])  # Drop items with quantities less than precision of calculation.
# Out:
# You'll be eating (in 100s of grams or milliliters):
# almond milk    5.342832
# black beans    1.517246
# green beans    4.506103
# squash         9.307355
# dtype: float64

# %%
 tab = pd.DataFrame({"Outcome":np.abs(A).dot(diet),"Recommendation":np.abs(b[group])})
print("\nWith the following nutritional outcomes of interest:")
tab
# Out:
# With the following nutritional outcomes of interest:
#                                     Outcome  Recommendation
# Nutrition
# Energy                          2340.082331          2000.0
# Protein                           58.080550            46.0
# Fiber, total dietary              37.153621            28.0
# Folate, DFE                      400.000000           400.0
# Calcium, Ca                     1744.768775          1000.0
# Carbohydrate, by difference      143.794228           130.0
# Iron, Fe                          19.924778            18.0
# Magnesium, Mg                    746.279886           310.0
# Niacin                            14.950483            14.0
# Phosphorus, P                   1372.318069           700.0
# Potassium, K                    6826.776380          4700.0
# Riboflavin                         1.100000             1.1
# Thiamin                            1.326950             1.1
# Vitamin A, RAE                  5109.226699           700.0
# Vitamin B-12                       2.400000             2.4
# Vitamin B-6                        2.068693             1.3
# Vitamin C, total ascorbic acid   250.428922            75.0
# Vitamin E (alpha-tocopherol)      15.250094            15.0
# Vitamin K (phylloquinone)        204.000526            90.0
# Zinc, Zn                           8.000000             8.0
# Sodium, Na                       380.668534          2300.0
# Energy                          2340.082331          3100.0

# %%
print("\nConstraining nutrients are:")
excess = tab.diff(axis=1).iloc[:,1]
print(excess.loc[np.abs(excess) < tol].index.tolist())
# Out:
# Constraining nutrients are:
# ['Folate, DFE', 'Riboflavin', 'Vitamin B-12', 'Zinc, Zn']

# %% [markdown]
# # Stigler's Solution: #

# %%
from  scipy.optimize import linprog as lp
import numpy as np
import warnings

def solve_subsistence_problem(FoodNutrients,Prices,dietmin,dietmax,max_weight=None,tol=1e-6):
    """Solve Stigler's Subsistence Cost Problem.

    Inputs:
       - FoodNutrients : A pd.DataFrame with rows corresponding to foods, columns to nutrients.
       - Prices : A pd.Series of prices for different foods
       - diet_min : A pd.Series of DRIs, with index corresponding to columns of FoodNutrients,
                    describing minimum intakes.
       - diet_max : A pd.Series of DRIs, with index corresponding to columns of FoodNutrients,
                    describing maximum intakes.
       - max_weight : Maximum weight (in hectograms) allowed for diet.
       - tol : Solution values smaller than this in absolute value treated as zeros.
       
    """
    try: 
        p = Prices.apply(lambda x:x.magnitude)
    except AttributeError:  # Maybe not passing in prices with units?
        warnings.warn("Prices have no units.  BE CAREFUL!  We're assuming prices are per hectogram or deciliter!")
        p = Prices

    p = p.dropna()

    # Compile list that we have both prices and nutritional info for; drop if either missing
    use = p.index.intersection(FoodNutrients.columns)
    p = p[use]

    # Drop nutritional information for foods we don't know the price of,
    # and replace missing nutrients with zeros.
    Aall = FoodNutrients[p.index].fillna(0)

    # Drop rows of A that we don't have constraints for.
    Amin = Aall.loc[Aall.index.intersection(dietmin.index)]
    Amin = Amin.reindex(dietmin.index,axis=0)
    idx = Amin.index.to_frame()
    idx['type'] = 'min'
    #Amin.index = pd.MultiIndex.from_frame(idx)
    #dietmin.index = Amin.index
    
    Amax = Aall.loc[Aall.index.intersection(dietmax.index)]
    Amax = Amax.reindex(dietmax.index,axis=0)
    idx = Amax.index.to_frame()
    idx['type'] = 'max'
    #Amax.index = pd.MultiIndex.from_frame(idx)
    #dietmax.index = Amax.index

    # Minimum requirements involve multiplying constraint by -1 to make <=.
    A = pd.concat([Amin,
                   -Amax])

    b = pd.concat([dietmin,
                   -dietmax]) # Note sign change for max constraints

    # Make sure order of p, A, b are consistent
    A = A.reindex(p.index,axis=1)
    A = A.reindex(b.index,axis=0)

    if max_weight is not None:
        # Add up weights of foods consumed
        A.loc['Hectograms'] = -1
        b.loc['Hectograms'] = -max_weight
        
    # Now solve problem!  (Note that the linear program solver we'll use assumes
    # "less-than-or-equal" constraints.  We can switch back and forth by
    # multiplying $A$ and $b$ by $-1$.)

    result = lp(p, -A, -b, method='highs')

    result.A = A
    result.b = b
    
    if result.success:
        result.diet = pd.Series(result.x,index=p.index)
    else: # No feasible solution?
        warnings.warn(result.message)
        result.diet = pd.Series(result.x,index=p.index)*np.nan  

    return result

# %%
apikey = "ngZTL3EoRoYFex00m5L4bdOdbtctFiuu7MT4cTeM"
SHEETs = [("https://docs.google.com/spreadsheets/d/1CBbHwj62DyYoIubexC1uNchOYTM_qtdTCIVG-jco72s/edit#gid=75959120","Keto Food Prices"),]
df = read_sheets(SHEETs[0][0])[SHEETs[0][1]]
df
# Out:
# Key available for students@eep153.iam.gserviceaccount.com.
# /srv/conda/lib/python3.9/site-packages/eep153_tools/sheets.py:150: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   D[w.title]=df.apply(lambda x: pd.to_numeric(x,errors='ignore'))
#                                      Food  Quantity  Units  Price     Date  \
# 0                                  salmon      7.00     oz   8.99  2/20/24
# 1                                    tuna      5.00     oz   1.29  2/20/24
# 2                                 chicken      1.25  pound   4.99  2/20/24
# 3                          cottage cheese     16.00     oz   2.99  2/20/24
# 4                            greek yogurt     32.00     oz   6.99  2/20/24
# 5                                 spinach      8.00     oz   2.49  2/20/24
# 6                                 carrots      1.00  pound   1.49  2/20/24
# 7                                    kale     10.00     oz   3.99  2/20/24
# 8                          collard greens      1.00  pound   3.49  2/20/24
# 9                            coconut milk     13.50   floz   2.29  2/20/24
# 10                                 squash      2.00  pound   1.20  2/23/24
# 11                            cauliflower      1.00  pound   3.99  2/20/24
# 12                               broccoli      1.00  pound   3.49  2/20/24
# 13                              asparagus      1.00  pound   4.99  2/20/24
# 14                            green beans     24.00     oz   1.99  2/20/24
# 15                                almonds     16.00     oz  10.99  2/20/24
# 16                             chia seeds     16.00     oz   7.99  2/20/24
# 17                              olive oil     17.00   floz   7.99  2/20/24
# 18                            almond milk     64.00   floz   3.49  2/20/24
# 19                            cod fillets      1.00  pound  10.99  2/20/24
# 20                              pork loin      1.50  pound   8.99  2/20/24
# 21           ground beef 80% lean 20% fat      1.00  pound   4.99  2/20/24
# 22                                avocado      5.40     oz   1.00  2/20/24
# 23                                    egg     12.00    egg   5.49  2/20/24
# 24                            coconut oil     14.00   floz   6.99  2/20/24
# 25                           almond flour     16.00     oz   9.49  2/20/24
# 26                             mayonnaise     15.00   floz   3.49  2/20/24
# 27                                cabbage      2.00  pound   2.98  2/20/24
# 28                      green bell pepper      0.33  pound   1.00  2/20/24
# 29                                  bacon      8.00     oz   4.99  2/20/24
# 30                          ground turkey      1.00  pound   4.49  2/20/24
# 31                                   tofu     14.00     oz   3.49  2/20/24
# 32                                  kefir     32.00     oz   5.99  2/20/24
# 33                             hemp seeds      8.00     oz  12.79  2/20/24
# 34                         frozen berries     12.00     oz   4.50  2/20/24
# 35                        zuchini noodles     12.00     oz   4.99  2/20/24
# 36                                peanuts     16.00     oz   2.99  2/20/24
# 37                                walnuts     16.00     oz   5.00  2/20/24
# 38                      manzanilla olives     14.50     oz   2.99  2/20/24
# 39                                  apple      0.33  pound   0.49  2/20/24
# 40                                  apple      5.00  pound   3.99  2/20/24
# 41                                 tomato      0.33  pound   0.87  2/20/24
# 42                                   spam      1.00     oz   3.99  2/20/24
# 43                            black beans     15.50     oz   1.09  2/20/24
# 44                       cauliflower rice     12.00     oz   1.99  2/20/24
# 45           creamy almond butter no salt     16.00     oz   5.99  2/20/24
# 46            creamy salted peanut butter     16.00     oz   2.49  2/20/24
# 47                           wild arugula      7.00     oz   2.29  2/20/24
# 48  traditional whole milk ricotta cheese     16.00     oz   3.99  2/20/24
#
#        Location      FDC
# 0       Safeway   175167
# 1       Safeway   175156
# 2       Safeway  2646171
# 3       Safeway  2346384
# 4       Safeway  2259794
# 5       Safeway  1999632
# 6       Safeway  2258586
# 7       Safeway   323505
# 8   trader joes   170406
# 9       Safeway   170173
# 10      Safeway   169295
# 11      Safeway   169986
# 12      Safeway   170379
# 13      Safeway   168389
# 14  trader joes   169961
# 15      Safeway  2346393
# 16      Safeway   170554
# 17      Safeway   748608
# 18      Safeway  2257045
# 19  trader joes   171955
# 20      Safeway  2646169
# 21  trader joes  2514744
# 22      Safeway   171706
# 23      Safeway   748967
# 24      Safeway   330458
# 25      Safeway  2261420
# 26      Safeway   167736
# 27      Safeway   169975
# 28       Safway  2258588
# 29  trader joes   749420
# 30  trader joes  2514747
# 31      Safeway   174292
# 32     Safeway    170904
# 33     Safeway    170148
# 34      Safeway  2344766
# 35     Safeway   2435691
# 36     Safeway   2515376
# 37     Safeway   2346394
# 38  trader joes   332791
# 39     Safeway   1750339
# 40      Safeway  2512381
# 41      Safeway  1999634
# 42      Safeway   174594
# 43  trader joes   747444
# 44  trader joes  2377843
# 45   trade joes  1990977
# 46  trader joes  2465753
# 47  trader joes  2510503
# 48  trader joes  2055810

# %%
D = {}
count = 0
for food in  df.Food.tolist():
    try:
        FDC = df.loc[df.Food==food,:].FDC[count]
        count+=1
        D[food] = fdc.nutrients(apikey,FDC).Quantity
    except AttributeError: 
        warnings.warn("Couldn't find FDC Code %s for food %s." % (food,FDC))        
FoodNutrients = pd.DataFrame(D,dtype=float)

# %%
# Convert food quantities to FDC units
df['FDC Quantity'] = df[['Quantity','Units']].T.apply(lambda x : fdc.units(x['Quantity'],x['Units']))

# Now may want to filter df by time or place--need to get a unique set of food names.
df['FDC Price'] = df['Price']/df['FDC Quantity']

df.dropna(how='any') # Drop food with any missing data

# To use minimum price observed
# Out:
# /srv/conda/lib/python3.9/site-packages/pandas/core/dtypes/cast.py:1598: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   result[:] = values
#                                      Food  Quantity  Units  Price     Date  \
# 0                                  salmon      7.00     oz   8.99  2/20/24
# 1                                    tuna      5.00     oz   1.29  2/20/24
# 2                                 chicken      1.25  pound   4.99  2/20/24
# 3                          cottage cheese     16.00     oz   2.99  2/20/24
# 4                            greek yogurt     32.00     oz   6.99  2/20/24
# 5                                 spinach      8.00     oz   2.49  2/20/24
# 6                                 carrots      1.00  pound   1.49  2/20/24
# 7                                    kale     10.00     oz   3.99  2/20/24
# 8                          collard greens      1.00  pound   3.49  2/20/24
# 9                            coconut milk     13.50   floz   2.29  2/20/24
# 10                                 squash      2.00  pound   1.20  2/23/24
# 11                            cauliflower      1.00  pound   3.99  2/20/24
# 12                               broccoli      1.00  pound   3.49  2/20/24
# 13                              asparagus      1.00  pound   4.99  2/20/24
# 14                            green beans     24.00     oz   1.99  2/20/24
# 15                                almonds     16.00     oz  10.99  2/20/24
# 16                             chia seeds     16.00     oz   7.99  2/20/24
# 17                              olive oil     17.00   floz   7.99  2/20/24
# 18                            almond milk     64.00   floz   3.49  2/20/24
# 19                            cod fillets      1.00  pound  10.99  2/20/24
# 20                              pork loin      1.50  pound   8.99  2/20/24
# 21           ground beef 80% lean 20% fat      1.00  pound   4.99  2/20/24
# 22                                avocado      5.40     oz   1.00  2/20/24
# 23                                    egg     12.00    egg   5.49  2/20/24
# 24                            coconut oil     14.00   floz   6.99  2/20/24
# 25                           almond flour     16.00     oz   9.49  2/20/24
# 26                             mayonnaise     15.00   floz   3.49  2/20/24
# 27                                cabbage      2.00  pound   2.98  2/20/24
# 28                      green bell pepper      0.33  pound   1.00  2/20/24
# 29                                  bacon      8.00     oz   4.99  2/20/24
# 30                          ground turkey      1.00  pound   4.49  2/20/24
# 31                                   tofu     14.00     oz   3.49  2/20/24
# 32                                  kefir     32.00     oz   5.99  2/20/24
# 33                             hemp seeds      8.00     oz  12.79  2/20/24
# 34                         frozen berries     12.00     oz   4.50  2/20/24
# 35                        zuchini noodles     12.00     oz   4.99  2/20/24
# 36                                peanuts     16.00     oz   2.99  2/20/24
# 37                                walnuts     16.00     oz   5.00  2/20/24
# 38                      manzanilla olives     14.50     oz   2.99  2/20/24
# 39                                  apple      0.33  pound   0.49  2/20/24
# 40                                  apple      5.00  pound   3.99  2/20/24
# 41                                 tomato      0.33  pound   0.87  2/20/24
# 42                                   spam      1.00     oz   3.99  2/20/24
# 43                            black beans     15.50     oz   1.09  2/20/24
# 44                       cauliflower rice     12.00     oz   1.99  2/20/24
# 45           creamy almond butter no salt     16.00     oz   5.99  2/20/24
# 46            creamy salted peanut butter     16.00     oz   2.49  2/20/24
# 47                           wild arugula      7.00     oz   2.29  2/20/24
# 48  traditional whole milk ricotta cheese     16.00     oz   3.99  2/20/24
#
#        Location      FDC                   FDC Quantity  \
# 0       Safeway   175167   1.9844666187500002 hectogram
# 1       Safeway   175156   1.4174761562500002 hectogram
# 2       Safeway  2646171    5.669904625000001 hectogram
# 3       Safeway  2346384    4.535923700000001 hectogram
# 4       Safeway  2259794    9.071847400000001 hectogram
# 5       Safeway  1999632   2.2679618500000003 hectogram
# 6       Safeway  2258586    4.535923700000001 hectogram
# 7       Safeway   323505   2.8349523125000005 hectogram
# 8   trader joes   170406    4.535923700000001 hectogram
# 9       Safeway   170173   3.9924264909374987 deciliter
# 10      Safeway   169295    9.071847400000001 hectogram
# 11      Safeway   169986    4.535923700000001 hectogram
# 12      Safeway   170379    4.535923700000001 hectogram
# 13      Safeway   168389    4.535923700000001 hectogram
# 14  trader joes   169961           6.80388555 hectogram
# 15      Safeway  2346393    4.535923700000001 hectogram
# 16      Safeway   170554    4.535923700000001 hectogram
# 17      Safeway   748608    5.027500025624998 deciliter
# 18      Safeway  2257045   18.927058919999993 deciliter
# 19  trader joes   171955    4.535923700000001 hectogram
# 20      Safeway  2646169           6.80388555 hectogram
# 21  trader joes  2514744    4.535923700000001 hectogram
# 22      Safeway   171706   1.5308742487500002 hectogram
# 23      Safeway   748967                 nan milliliter
# 24      Safeway   330458    4.140294138749999 deciliter
# 25      Safeway  2261420    4.535923700000001 hectogram
# 26      Safeway   167736    4.436029434374999 deciliter
# 27      Safeway   169975    9.071847400000001 hectogram
# 28       Safway  2258588   1.4968548210000003 hectogram
# 29  trader joes   749420   2.2679618500000003 hectogram
# 30  trader joes  2514747    4.535923700000001 hectogram
# 31      Safeway   174292   3.9689332375000004 hectogram
# 32     Safeway    170904    9.071847400000001 hectogram
# 33     Safeway    170148   2.2679618500000003 hectogram
# 34      Safeway  2344766          3.401942775 hectogram
# 35     Safeway   2435691          3.401942775 hectogram
# 36     Safeway   2515376    4.535923700000001 hectogram
# 37     Safeway   2346394    4.535923700000001 hectogram
# 38  trader joes   332791       4.110680853125 hectogram
# 39     Safeway   1750339   1.4968548210000003 hectogram
# 40      Safeway  2512381   22.679618500000004 hectogram
# 41      Safeway  1999634   1.4968548210000003 hectogram
# 42      Safeway   174594  0.28349523125000003 hectogram
# 43  trader joes   747444       4.394176084375 hectogram
# 44  trader joes  2377843          3.401942775 hectogram
# 45   trade joes  1990977    4.535923700000001 hectogram
# 46  trader joes  2465753    4.535923700000001 hectogram
# 47  trader joes  2510503   1.9844666187500002 hectogram
# 48  trader joes  2055810    4.535923700000001 hectogram
#
#                           FDC Price
# 0    4.5301845418103985 / hectogram
# 1    0.9100682182991745 / hectogram
# 2    0.8800853506420312 / hectogram
# 3     0.659182163932784 / hectogram
# 4     0.770515606336147 / hectogram
# 5    1.0979020656806904 / hectogram
# 6   0.32848877065546755 / hectogram
# 7    1.4074310817882583 / hectogram
# 8    0.7694132950252227 / hectogram
# 9    0.5735860147201518 / deciliter
# 10  0.13227735731092652 / hectogram
# 11   0.8796444261176615 / hectogram
# 12   0.7694132950252227 / hectogram
# 13    1.100106688302539 / hectogram
# 14  0.29247993449860427 / hectogram
# 15   2.4228802614118043 / hectogram
# 16   1.7614934748571718 / hectogram
# 17   1.5892590669866216 / deciliter
# 18  0.18439209254598768 / deciliter
# 19   2.4228802614118043 / hectogram
# 20   1.3213038246946995 / hectogram
# 21    1.100106688302539 / hectogram
# 22   0.6532215175848224 / hectogram
# 23                 nan / milliliter
# 24   1.6882858477563043 / deciliter
# 25    2.092186868134488 / hectogram
# 26   0.7867395948628807 / deciliter
# 27  0.32848877065546755 / hectogram
# 28   0.6680674611662956 / hectogram
# 29    2.200213376605078 / hectogram
# 30   0.9898755572101002 / hectogram
# 31   0.8793294800288259 / hectogram
# 32   0.6602844752437083 / hectogram
# 33    5.639424666689168 / hectogram
# 34   1.3227735731092654 / hectogram
# 35   1.4668089177367187 / hectogram
# 36    0.659182163932784 / hectogram
# 37   1.1023113109243878 / hectogram
# 38   0.7273734222706582 / hectogram
# 39  0.32735305597148484 / hectogram
# 40  0.17592888522353228 / hectogram
# 41   0.5812186912146772 / hectogram
# 42   14.074310817882584 / hectogram
# 43  0.24805560338737195 / hectogram
# 44   0.5849598689972085 / hectogram
# 45   1.3205689504874165 / hectogram
# 46   0.5489510328403452 / hectogram
# 47   1.1539624694934163 / hectogram
# 48   0.8796444261176615 / hectogram

# %%
from eep153_tools.sheets import read_sheets

DRI_url = "https://docs.google.com/spreadsheets/d/1M1l9Md7X4Amaiecz0SBRsve-skrV_rD7O7ylWOeVpOw"

DRIs = read_sheets(DRI_url)

# Define *minimums*
diet_min = DRIs['diet_minimums'].set_index('Nutrition')

# Define *maximums*
diet_max = DRIs['diet_maximums'].set_index('Nutrition')
# Out:
# Key available for students@eep153.iam.gserviceaccount.com.
# /srv/conda/lib/python3.9/site-packages/eep153_tools/sheets.py:150: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   D[w.title]=df.apply(lambda x: pd.to_numeric(x,errors='ignore'))
# /srv/conda/lib/python3.9/site-packages/eep153_tools/sheets.py:150: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   D[w.title]=df.apply(lambda x: pd.to_numeric(x,errors='ignore'))
# /srv/conda/lib/python3.9/site-packages/eep153_tools/sheets.py:150: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   D[w.title]=df.apply(lambda x: pd.to_numeric(x,errors='ignore'))

# %%
group = 'M 19-30'
tol = 1e-6

result = solve_subsistence_problem(FoodNutrients,Prices,
                                  diet_min[group],diet_max[group],max_weight=12,tol=tol)

print("Cost of diet for %s is $%4.2f per day.\n" % (group,result.fun))

# Put back into nice series
diet = result.diet

print("\nDiet (in 100s of grams or milliliters):")
print(diet[diet >= tol])  # Drop items with quantities less than precision of calculation.
print()

tab = pd.DataFrame({"Outcome":np.abs(result.A).dot(diet),"Recommendation":np.abs(result.b)})
print("\nWith the following nutritional outcomes of interest:")
print(tab)
print()

print("\nConstraining nutrients are:")
excess = tab.diff(axis=1).iloc[:,1]
print(excess.loc[np.abs(excess) < tol*100].index.tolist())
# Out:
# Cost of diet for M 19-30 is $10.43 per day.
#
#
# Diet (in 100s of grams or milliliters):
# almond milk       2.038541
# black beans       3.707161
# collard greens    2.447604
# hemp seeds        0.676079
# kale              1.350046
# mayonnaise        0.681639
# tuna              1.098929
# dtype: float64
#
#
# With the following nutritional outcomes of interest:
#                                     Outcome  Recommendation
# Nutrition
# Energy                          4525.184729     2400.000000
# Fiber, total dietary              33.600000       33.600000
# Folate, DFE                      400.000000      400.000000
# Calcium, Ca                     2023.859964     1000.000000
# Iron, Fe                          30.266160        8.000000
# Magnesium, Mg                   1305.637119      400.000000
# Niacin                            26.740352       16.000000
# Phosphorus, P                   3486.009357      700.000000
# Potassium, K                    8068.724767     4700.000000
# Riboflavin                         1.300000        1.300000
# Thiamin                            1.200000        1.200000
# Vitamin A, RAE                   957.968849      900.000000
# Vitamin B-12                       3.003679        2.400000
# Vitamin B-6                        1.948865        1.300000
# Vitamin C, total ascorbic acid   213.931738       90.000000
# Vitamin E (alpha-tocopherol)      15.000000       15.000000
# Vitamin K (phylloquinone)       1613.202478      120.000000
# Zinc, Zn                          21.372735       11.000000
# Protein                          148.639919      150.000000
# Carbohydrate, by difference       26.666667       26.666667
# Hectograms                        12.000000       12.000000
#
#
# Constraining nutrients are:
# ['Fiber, total dietary', 'Folate, DFE', 'Riboflavin', 'Thiamin', 'Vitamin E (alpha-tocopherol)', 'Carbohydrate, by difference', 'Hectograms']

# %%
import cufflinks as cf
cf.go_offline()

ReferenceGood = 'squash'

scale = [0.5,0.75,0.9,1.,1.1,1.2,1.3,1.4,1.5,2,4]

cost0 = solve_subsistence_problem(FoodNutrients,Prices,
                                  diet_min[group],diet_max[group],max_weight=12,tol=tol).fun

my_p = Prices.copy()

diet = {}
for s in scale:

    my_p[ReferenceGood] = Prices[ReferenceGood]*s
    result = solve_subsistence_problem(FoodNutrients,my_p,
                                       diet_min[group],diet_max[group],max_weight=12,tol=tol)
    diet[my_p[ReferenceGood]] = result.diet

Diet_response = pd.DataFrame(diet).T
Diet_response.index.name = '%s Price' % ReferenceGood

Diet_response.reset_index(inplace=True)

# Get rid of units for index (cufflinks chokes)
Diet_response['%s Price' % ReferenceGood] = Diet_response['%s Price' % ReferenceGood].apply(lambda x: x.magnitude)

Diet_response = Diet_response.set_index('%s Price' % ReferenceGood)

# Just look at goods consumed in quantities greater than error tolerance
Diet_response.loc[:,(Diet_response>tol).sum()>0].iplot(xTitle='%s Price' % ReferenceGood,yTitle='Hectograms')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.29.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# /srv/conda/lib/python3.9/site-packages/pandas/core/dtypes/cast.py:1598: UnitStrippedWarning:
#
# The unit of the quantity is stripped when downcasting to ndarray.

# %%
# Matrix product maps quantities of food into quantities of nutrients
FoodNutrients = FoodNutrients.drop(columns = 'egg')
FoodNutrients = FoodNutrients.fillna(0)
NutrientResponse = Diet_response@FoodNutrients.T

# Drop columns of missing nutrients
NutrientResponse = NutrientResponse.loc[:,NutrientResponse.count()>0]
NutrientResponse.iplot(xTitle='%s Price' % ReferenceGood,yTitle='Nutrients')

# %%
cf.go_offline()

scale = [.5,.6,.7,.8,.9,1.,1.1,1.2,1.3,1.4,1.5]

cost0 = solve_subsistence_problem(FoodNutrients,Prices,diet_min[group],diet_max[group],tol=tol).fun

Price_response={}
for s in scale:
    cost = {}
    for i,p in enumerate(Prices):
        my_p = Prices.copy()
        my_p.iloc[i] = p*s
        result = solve_subsistence_problem(FoodNutrients,my_p,diet_min[group],diet_max[group],tol=tol)
        cost[Prices.index[i]] = np.log(result.fun/cost0)
    Price_response[np.log(s)] = cost

Price_response = pd.DataFrame(Price_response).T
Price_response.iplot(xTitle='change in log price',yTitle='change in log cost')
